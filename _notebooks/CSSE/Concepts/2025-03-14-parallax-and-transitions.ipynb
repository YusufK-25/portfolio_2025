# %%
---
toc: true
layout: post
title: parallax-and-transformations
description: Teaches about parallax
menu: nav/transallax
permalink: /game/transallax
courses: csse
type: ccc
author: Santhosh, Aria, Nicholas, Yusuf, 
---
